# %%
from ncclient import manager
import xmltodict
import json

HOST = 'r1.udx'
PORT = 8321
USER = 'admin'
PASS = 'admin'
name = 'default'


def get(HOST, PORT, USER, PASS):
    with manager.connect(host=HOST, port=PORT, username=USER, password=PASS,
                         hostkey_verify=False, device_params={'name': name},
                         look_for_keys=False, allow_agent=False) as m:
        return m.get().data_xml


def get_config(HOST, PORT, USER, PASS):
    with manager.connect(host=HOST, port=PORT, username=USER, password=PASS,
                         hostkey_verify=False, device_params={'name': name},
                         look_for_keys=False, allow_agent=False) as m:
        return m.get_config(source='running').data_xml
    
    
def get_capabilities(HOST, PORT, USER, PASS):

    with manager.connect(host=HOST, port=PORT, username=USER, password=PASS,
                         hostkey_verify=False, device_params={'name': name},
                         look_for_keys=False, allow_agent=False) as m:
        return m.server_capabilities

# %%
# capabilitis = get_capabilities(HOST, PORT, USER, PASS)

# %%
running_xml = get_config(HOST, PORT, USER, PASS)

# %%
# for capability in capabilitis:
#     print(capability)

# %%
running_dict = xmltodict.parse(running_xml)
running_json = json.dumps(running_dict, indent=4)

# %%
print(running_xml)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <host-names xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-cfg">
#    <host-name>r1</host-name>
#   </host-names>
#   <call-home xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-call-home-cfg">
#    <active/>
#    <contact-smart-licensing>true</contact-smart-licensing>
#    <profiles>
#     <profile>
#      <profile-name>CiscoTAC-1</profile-name>
#      <create/>
#      <active/>
#      <methods>
#       <method>
#        <method>email</method>
#        <enable>false</enable>
#       </method>
#       <method>
#        <method>http</method>
#        <enable>true</enable>
#       </method>
#      </methods>
#     </profile>
#    </profiles>
#   </call-home>
#   <interface-configurations xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-cfg">
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>MgmtEth0/RP0/CPU0/0</interface-name>
#     <description>*** MANAGEMENT INTERFACE ***</description>
#     <ipv4-network xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-cfg">
#      <addresses>
#       <dhcp>
#        <enabled/>
#        <pattern>MgmtEth0_RP0_CPU0_0</pattern>
#       </dhcp>
#      </addresses>
#     </ipv4-network>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/0</interface-name>
#     <shutdown/>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/1</interface-name>
#     <shutdown/>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/2</interface-name>
#     <shutdown/>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/3</interface-name>
#     <shutdown/>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/4</interface-name>
#     <shutdown/>
#    </interface-configuration>
#   </interface-configurations>
#   <banners xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-infra-infra-cfg">
#    <banner>
#     <banner-name>motd</banner-name>
#     <banner-text>;
# --------------------------------------------------------------------------
#   Router 1 (Cisco IOS XR Sandbox)
# --------------------------------------------------------------------------
# ;</banner-text>
#    </banner>
#   </banners>
#   <aaa xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-cfg">
#    <usernames xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg">
#     <username>
#      <ordering-index>0</ordering-index>
#      <name>admin</name>
#      <usergroup-under-usernames>
#       <usergroup-under-username>
#        <name>root-lr</name>
#       </usergroup-under-username>
#       <usergroup-under-username>
#        <name>cisco-support</name>
#       </usergroup-under-username>
#      </usergroup-under-usernames>
#      <secret>$1$A4C9$oaNorr6BXDruE4gDd086L.</secret>
#     </username>
#    </usernames>
#   </aaa>
#   <vty xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-tty-vty-cfg">
#    <vty-pools>
#     <vty-pool>
#      <pool-name>default</pool-name>
#      <first-vty>0</first-vty>
#      <last-vty>4</last-vty>
#      <line-template>VTY-TEMPLATE</line-template>
#     </vty-pool>
#    </vty-pools>
#   </vty>
#   <ssh xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-ssh-cfg">
#    <server>
#     <v2/>
#     <netconf-vrf-table>
#      <vrf>
#       <vrf-name>default</vrf-name>
#       <enable/>
#      </vrf>
#     </netconf-vrf-table>
#    </server>
#   </ssh>
#   <netconf-yang xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-man-netconf-cfg">
#    <agent>
#     <ssh>
#      <enable/>
#     </ssh>
#    </agent>
#   </netconf-yang>
#   <tty xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-tty-server-cfg">
#    <tty-lines>
#     <tty-line>
#      <name>console</name>
#      <exec>
#       <time-stamp>false</time-stamp>
#       <timeout>
#        <minutes>0</minutes>
#        <seconds>0</seconds>
#       </timeout>
#      </exec>
#     </tty-line>
#    </tty-lines>
#   </tty>
#   <syslog-service xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-infra-syslog-cfg">
#    <timestamps>
#     <log>
#      <log-datetime>
#       <log-datetime-value>
#        <msec>enable</msec>
#       </log-datetime-value>
#      </log-datetime>
#     </log>
#     <debug>
#      <debug-datetime>
#       <datetime-value>
#        <msec>enable</msec>
#       </datetime-value>
#      </debug-datetime>
#     </debug>
#    </timestamps>
#   </syslog-service>
#   <router-static xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ip-static-cfg">
#    <default-vrf>
#     <address-family>
#      <vrfipv4>
#       <vrf-unicast>
#        <vrf-prefixes>
#         <vrf-prefix>
#          <prefix>0.0.0.0</prefix>
#          <prefix-length>0</prefix-length>
#          <vrf-route>
#           <vrf-next-hop-table>
#            <vrf-next-hop-next-hop-address>
#             <next-hop-address>192.168.122.1</next-hop-address>
#            </vrf-next-hop-next-hop-address>
#           </vrf-next-hop-table>
#          </vrf-route>
#         </vrf-prefix>
#        </vrf-prefixes>
#       </vrf-unicast>
#      </vrfipv4>
#     </address-family>
#    </default-vrf>
#   </router-static>
#   <aaa xmlns="http://tail-f.com/ns/aaa/1.1">
#    <authentication>
#     <users>
#      <user>
#       <name>admin</name>
#       <uid>9000</uid>
#       <gid>100</gid>
#       <password>$1$1hD9$xG4Q4FDr.ptf9nyEHLDkI1</password>
#       <ssh_keydir>/var/confd/homes/admin/.ssh</ssh_keydir>
#       <homedir>/var/confd/homes/admin</homedir>
#      </user>
#     </users>
#     <groups>
#      <group>
#       <name>aaa-r</name>
#       <gid>100</gid>
#       <users>%%__system_user__%%</users>
#      </group>
#      <group>
#       <name>admin-r</name>
#       <gid>100</gid>
#       <users>%%__system_user__%%</users>
#      </group>
#      <group>
#       <name>root-system</name>
#       <gid>100</gid>
#       <users>%%__system_user__%% admin</users>
#      </group>
#     </groups>
#    </authentication>
#    <authorization>
#     <cmdrules>
#      <cmdrule>
#       <index>1</index>
#       <context>*</context>
#       <command>*</command>
#       <group>root-system</group>
#       <ops>rx</ops>
#       <action>accept</action>
#      </cmdrule>
#      <cmdrule>
#       <index>2</index>
#       <context>*</context>
#       <command>show running-config aaa</command>
#       <group>aaa-r</group>
#       <ops>rx</ops>
#       <action>accept</action>
#      </cmdrule>
#      <cmdrule>
#       <index>3</index>
#       <context>*</context>
#       <command>show tech-support aaa</command>
#       <group>aaa-r</group>
#       <ops>rx</ops>
#       <action>accept</action>
#      </cmdrule>
#      <cmdrule>
#       <index>4</index>
#       <context>*</context>
#       <command>show aaa</command>
#       <group>aaa-r</group>
#       <ops>rx</ops>
#       <action>accept</action>
#      </cmdrule>
#      <cmdrule>
#       <index>5</index>
#       <context>*</context>
#       <command>show</command>
#       <group>admin-r</group>
#       <ops>rx</ops>
#       <action>accept</action>
#      </cmdrule>
#     </cmdrules>
#     <datarules>
#      <datarule>
#       <index>1</index>
#       <namespace>*</namespace>
#       <context>*</context>
#       <keypath>*</keypath>
#       <group>root-system</group>
#       <ops>rwx</ops>
#       <action>accept</action>
#      </datarule>
#      <datarule>
#       <index>2</index>
#       <namespace>*</namespace>
#       <context>*</context>
#       <keypath>/aaa</keypath>
#       <group>aaa-r</group>
#       <ops>r</ops>
#       <action>accept</action>
#      </datarule>
#      <datarule>
#       <index>3</index>
#       <namespace>*</namespace>
#       <context>*</context>
#       <keypath>/aaa</keypath>
#       <group>admin-r</group>
#       <ops>rwx</ops>
#       <action>reject</action>
#      </datarule>
#      <datarule>
#       <index>4</index>
#       <namespace>*</namespace>
#       <context>*</context>
#       <keypath>/</keypath>
#       <group>admin-r</group>
#       <ops>r</ops>
#       <action>accept</action>
#      </datarule>
#     </datarules>
#    </authorization>
#   </aaa>
#   <confdConfig xmlns="http://tail-f.com/ns/confd_dyncfg/1.0">
#    <hideGroup>
#     <name>advanced-grp</name>
#     <password/>
#    </hideGroup>
#    <encryptedStrings>
#     <DES3CBC>
#      <key1>0123456789ABCDEF</key1>
#      <key2>0123456789ABCDEF</key2>
#      <key3>0123456789ABCDEF</key3>
#      <initVector>0123456789ABCDEF</initVector>
#     </DES3CBC>
#     <AESCFB128>
#      <key>0123456789ABCDEF0123456789ABCDEF</key>
#      <initVector>0123456789ABCDEF0123456789ABCDEF</initVector>
#     </AESCFB128>
#    </encryptedStrings>
#    <logs>
#     <syslogConfig>
#      <version>bsd</version>
#      <facility>daemon</facility>
#      <udp>
#       <enabled>false</enabled>
#       <host>syslogsrv.example.com</host>
#       <port>514</port>
#      </udp>
#     </syslogConfig>
#     <confdLog>
#      <enabled>true</enabled>
#      <file>
#       <enabled>true</enabled>
#       <name>/var/log/confd_daemon.log</name>
#      </file>
#      <syslog>
#       <enabled>false</enabled>
#      </syslog>
#     </confdLog>
#     <developerLog>
#      <enabled>true</enabled>
#      <file>
#       <enabled>true</enabled>
#       <name>/var/log/confd_developer.log</name>
#      </file>
#      <syslog>
#       <enabled>false</enabled>
#      </syslog>
#     </developerLog>
#     <developerLogLevel>trace</developerLogLevel>
#     <auditLog>
#      <enabled>true</enabled>
#      <file>
#       <enabled>true</enabled>
#       <name>/var/log/confd_audit.log</name>
#      </file>
#      <syslog>
#       <enabled>false</enabled>
#      </syslog>
#     </auditLog>
#     <auditLogCommit>false</auditLogCommit>
#     <netconfLog>
#      <enabled>true</enabled>
#      <file>
#       <enabled>true</enabled>
#       <name>/var/log/confd_netconf.log</name>
#      </file>
#      <syslog>
#       <enabled>false</enabled>
#      </syslog>
#     </netconfLog>
#     <snmpLog>
#      <enabled>true</enabled>
#      <file>
#       <enabled>true</enabled>
#       <name>/var/log/confd_snmp.log</name>
#      </file>
#      <syslog>
#       <enabled>false</enabled>
#      </syslog>
#     </snmpLog>
#     <webuiAccessLog>
#      <enabled>false</enabled>
#      <dir>/var/log/confd_webui.log</dir>
#     </webuiAccessLog>
#     <netconfTraceLog>
#      <enabled>false</enabled>
#      <filename>/var/log/confd_netconf_trace.log</filename>
#      <format>pretty</format>
#     </netconfTraceLog>
#     <errorLog>
#      <enabled>true</enabled>
#      <filename>/var/log/confd_error.log</filename>
#      <maxSize>S1M</maxSize>
#     </errorLog>
#    </logs>
#    <cli>
#     <enabled>true</enabled>
#     <modeNameStyle>short</modeNameStyle>
#     <allowOverwriteOnCopy>false</allowOverwriteOnCopy>
#     <inheritPaginate>true</inheritPaginate>
#     <safeScriptExecution>true</safeScriptExecution>
#     <exitConfigModeOnCtrlC>false</exitConfigModeOnCtrlC>
#     <execNavigationCmds>false</execNavigationCmds>
#     <allowOldStyleModeCmds>false</allowOldStyleModeCmds>
#     <mixedMode>false</mixedMode>
#     <topLevelCmdsInSubMode>true</topLevelCmdsInSubMode>
#     <completionShowOldVal>true</completionShowOldVal>
#     <reportInvalidCompletionInput>true</reportInvalidCompletionInput>
#     <useShortEnabled>true</useShortEnabled>
#     <smartRenameFiltering>true</smartRenameFiltering>
#     <allowParenQuotes>false</allowParenQuotes>
#     <singleElemPattern>true</singleElemPattern>
#     <multiPatternOperation>any</multiPatternOperation>
#     <sortSubmodeCmds>true</sortSubmodeCmds>
#     <sortLocalCmds>true</sortLocalCmds>
#     <displayEmptyConfigContainers>true</displayEmptyConfigContainers>
#     <whoShowMode>true</whoShowMode>
#     <whoHistoryDateTimeFormat>short</whoHistoryDateTimeFormat>
#     <editWrapMode>wrap</editWrapMode>
#     <supportQuotedEOL>true</supportQuotedEOL>
#     <allowWildcard>true</allowWildcard>
#     <allowAllAsWildcard>false</allowAllAsWildcard>
#     <allowRangeExpression>true</allowRangeExpression>
#     <addExtraTableSpacing>false</addExtraTableSpacing>
#     <suppressRangeKeyword>false</suppressRangeKeyword>
#     <tableLabel>false</tableLabel>
#     <tableLookAhead>50</tableLookAhead>
#     <showTableLabelsIfMultiple>false</showTableLabelsIfMultiple>
#     <defaultTableBehavior>dynamic</defaultTableBehavior>
#     <allowTableOverflow>false</allowTableOverflow>
#     <tableOverflowTruncate>false</tableOverflowTruncate>
#     <allowTableCellWrap>false</allowTableCellWrap>
#     <showAllNs>false</showAllNs>
#     <leafPrompting>true</leafPrompting>
#     <auditLogMode>all</auditLogMode>
#     <transactions>true</transactions>
#     <transactionCtrlCmds>false</transactionCtrlCmds>
#     <style>c</style>
#     <completionShowMax>2000</completionShowMax>
#     <rollbackMax>1000</rollbackMax>
#     <rollbackNumbering>fixed</rollbackNumbering>
#     <rollbackNumberingInitial>10000</rollbackNumberingInitial>
#     <showDefaults>false</showDefaults>
#     <reallocateOperTrans>false</reallocateOperTrans>
#     <quickSshTeardown>false</quickSshTeardown>
#     <cAlignLeafValues>true</cAlignLeafValues>
#     <defaultPrefix/>
#     <jWarningPrefix>Warning:</jWarningPrefix>
#     <jAbortedPrefix>Aborted:</jAbortedPrefix>
#     <jErrorPrefix>Error:</jErrorPrefix>
#     <cWarningPrefix>Warning:</cWarningPrefix>
#     <cAbortedPrefix>Aborted:</cAbortedPrefix>
#     <cErrorPrefix>Error:</cErrorPrefix>
#     <invalidDataString>--ERROR--</invalidDataString>
#     <showKeyName>true</showKeyName>
#     <commitRetryTimeout>PT15S</commitRetryTimeout>
#     <timezone>local</timezone>
#     <utcOffset>0</utcOffset>
#     <oldDetailsArg>false</oldDetailsArg>
#     <withDefaults>false</withDefaults>
#     <trimDefaultShow>false</trimDefaultShow>
#     <trimDefaultSave>false</trimDefaultSave>
#     <banner/>
#     <bannerFile/>
#     <prompt1>\u@\h\M&gt;</prompt1>
#     <prompt2>\u@\h\M%</prompt2>
#     <cPrompt1>\H#</cPrompt1>
#     <cPrompt2>\H(\m)#</cPrompt2>
#     <cStylePromptInJStyle>false</cStylePromptInJStyle>
#     <promptHostnameDelimiter>.</promptHostnameDelimiter>
#     <asyncPromptRefresh>true</asyncPromptRefresh>
#     <showLogDirectory>/var/log/</showLogDirectory>
#     <idleTimeout>PT10M</idleTimeout>
#     <disableIdleTimeoutOnCmd>true</disableIdleTimeoutOnCmd>
#     <commandTimeout>infinity</commandTimeout>
#     <spaceCompletion>
#      <enabled>false</enabled>
#     </spaceCompletion>
#     <timestamp>
#      <enabled>true</enabled>
#     </timestamp>
#     <autoWizard>
#      <enabled>false</enabled>
#     </autoWizard>
#     <ssh>
#      <enabled>false</enabled>
#      <ip>0.0.0.0</ip>
#      <port>2024</port>
#      <extraIpPorts>[::]</extraIpPorts>
#      <banner/>
#      <bannerFile/>
#     </ssh>
#     <commitMessage>true</commitMessage>
#     <commitMessageFormat>\nSystem message at $(time)...\nCommit performed by $(user) via $(proto) using $(ctx).\n</commitMessageFormat>
#     <jShowCR>false</jShowCR>
#     <showPipe>true</showPipe>
#     <showPipeConfig>false</showPipeConfig>
#     <disablePipe>false</disablePipe>
#     <disablePipeConfig>false</disablePipeConfig>
#     <pipeHelpMode>always</pipeHelpMode>
#     <jAllowDeleteAll>true</jAllowDeleteAll>
#     <cSilentNo>true</cSilentNo>
#     <noFollowIncompleteCommand>false</noFollowIncompleteCommand>
#     <cRestrictiveNo>true</cRestrictiveNo>
#     <prioritizeSubmodeCmds>true</prioritizeSubmodeCmds>
#     <cExtendedCmdSearch>true</cExtendedCmdSearch>
#     <enterSubmodeOnLeaf>false</enterSubmodeOnLeaf>
#     <jExtendedShow>true</jExtendedShow>
#     <jShowUnset>false</jShowUnset>
#     <jShowUnsetText>UNSET</jShowUnsetText>
#     <jStatusFormat>[$(status)][$(time)]\n</jStatusFormat>
#     <cModeExitFormat>!</cModeExitFormat>
#     <forcedExitFormat>\nYou are forced out of configure mode by $(sender).\n</forcedExitFormat>
#     <showSubsystemMessages>false</showSubsystemMessages>
#     <ignoreSubsystemFailures>true</ignoreSubsystemFailures>
#     <showEmptyContainers>false</showEmptyContainers>
#     <showTags>true</showTags>
#     <showAnnotations>true</showAnnotations>
#     <jShowTableRecursive>false</jShowTableRecursive>
#     <cPrivate>false</cPrivate>
#     <cTab>false</cTab>
#     <cTabInfo>false</cTabInfo>
#     <tabExtend>true</tabExtend>
#     <cHelp>true</cHelp>
#     <restrictedFileAccess>false</restrictedFileAccess>
#     <hideDotFiles>false</hideDotFiles>
#     <restrictedFileRegexp/>
#     <historyRemoveDuplicates>false</historyRemoveDuplicates>
#     <historyMaxSize>1000</historyMaxSize>
#     <messageMaxSize>10000</messageMaxSize>
#     <mapActions>oper</mapActions>
#     <compactTable>true</compactTable>
#     <compactShow>false</compactShow>
#     <compactStatsShow>false</compactStatsShow>
#     <prettifyStatsName>false</prettifyStatsName>
#     <showCommitProgress>false</showCommitProgress>
#     <commitActivityClock>false</commitActivityClock>
#     <confirmUncommitedOnExit>prompt</confirmUncommitedOnExit>
#     <reconfirmHidden>false</reconfirmHidden>
#     <dequoteHidden>false</dequoteHidden>
#     <enumKeyInfo>false</enumKeyInfo>
#     <columnStats>false</columnStats>
#     <allowAbbrevCmds>true</allowAbbrevCmds>
#     <allowAbbrevCmdsOnLoad>true</allowAbbrevCmdsOnLoad>
#     <allowAbbrevKeys>false</allowAbbrevKeys>
#     <allowAbbrevParamNames>true</allowAbbrevParamNames>
#     <allowAbbrevEnums>true</allowAbbrevEnums>
#     <allowCaseInsensitiveEnums>true</allowCaseInsensitiveEnums>
#     <strictRefsOnLoad>false</strictRefsOnLoad>
#     <stopLoadOnError>true</stopLoadOnError>
#     <autocommitLoad>false</autocommitLoad>
#     <enableLoadMerge>true</enableLoadMerge>
#     <loadActivityClock>false</loadActivityClock>
#     <instanceDescription>true</instanceDescription>
#     <addErrorPrefixSuffix>true</addErrorPrefixSuffix>
#     <compListCompact>false</compListCompact>
#     <completionListLine>false</completionListLine>
#     <infoOnMatch>true</infoOnMatch>
#     <enableDisplayLevel>false</enableDisplayLevel>
#     <defaultDisplayLevel>99999999</defaultDisplayLevel>
#     <enableDisplayGroups>true</enableDisplayGroups>
#     <unifiedHistory>false</unifiedHistory>
#     <modeInfoInAAA>false</modeInfoInAAA>
#     <cmdAAAForAutowizard>false</cmdAAAForAutowizard>
#     <quoteStyle>backslash</quoteStyle>
#     <laxBarQuoting>false</laxBarQuoting>
#     <expandAliasEscape>false</expandAliasEscape>
#     <docWrap>true</docWrap>
#     <infoOnTab>true</infoOnTab>
#     <infoOnSpace>true</infoOnSpace>
#     <newLogout>true</newLogout>
#     <newInsert>true</newInsert>
#     <messageFormat>\nMessage from $(sender) at $(time)...\n$(message)\nEOF\n</messageFormat>
#     <messageWordWrap>false</messageWordWrap>
#     <messageQueueSize>10</messageQueueSize>
#     <promptEnumLimit>4</promptEnumLimit>
#     <caseInsensitive>true</caseInsensitive>
#     <caseInsensitiveKeys>true</caseInsensitiveKeys>
#     <ignoreLeadingWhitespace>false</ignoreLeadingWhitespace>
#     <indentTemplates>false</indentTemplates>
#     <wrapInfo>true</wrapInfo>
#     <wrapPrompt>false</wrapPrompt>
#     <sortShowElems>true</sortShowElems>
#     <showMatchBeforePossible>false</showMatchBeforePossible>
#     <possibleCompletionsFormat>Possible completions:</possibleCompletionsFormat>
#     <matchCompletionsFormat>Possible match completions:</matchCompletionsFormat>
#     <noMatchCompletionsFormat/>
#     <showDescription>true</showDescription>
#     <explicitSetCreate>false</explicitSetCreate>
#    </cli>
#    <snmpAgent>
#     <enabled>false</enabled>
#     <ip>0.0.0.0</ip>
#     <port>161</port>
#     <extraIpPorts>[::]</extraIpPorts>
#     <dscp>0</dscp>
#     <mibs>
#      <file>/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/CISCO-ENTITY-FRU-CONTROL-MIB.bin</file>
#      <file>/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/CISCO-ENTITY-SENSOR-MIB.bin</file>
#      <file>/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/ENTITY-MIB.bin</file>
#      <file>/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/ENTITY-STATE-MIB.bin</file>
#      <file>/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/ENTITY-STATE-TC-MIB.bin</file>
#      <file>/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/INET-ADDRESS-MIB.bin</file>
#      <file>SNMP-COMMUNITY-MIB.bin</file>
#      <file>SNMP-NOTIFICATION-MIB.bin</file>
#      <file>SNMP-TARGET-MIB.bin</file>
#      <file>SNMP-USER-BASED-SM-MIB.bin</file>
#      <file>SNMP-VIEW-BASED-ACM-MIB.bin</file>
#      <fromLoadPath>false</fromLoadPath>
#     </mibs>
#     <temporaryStorageTime>300</temporaryStorageTime>
#     <snmpVersions>
#      <v1>true</v1>
#      <v2c>true</v2c>
#      <v3>false</v3>
#     </snmpVersions>
#     <snmpEngine>
#      <snmpEngineID>80:00:61:81:05:01</snmpEngineID>
#      <snmpEngineMaxMessageSize>50000</snmpEngineMaxMessageSize>
#     </snmpEngine>
#     <authenticationFailureNotifyName/>
#     <system>
#      <sysDescr>Cisco Calvados SNMP agent</sysDescr>
#      <sysObjectID>1.3.6.1.4.1.24961</sysObjectID>
#      <sysServices>72</sysServices>
#      <sysORTable/>
#     </system>
#    </snmpAgent>
#    <netconf>
#     <enabled>true</enabled>
#     <transport>
#      <ssh>
#       <enabled>true</enabled>
#       <ip>0.0.0.0</ip>
#       <port>2022</port>
#       <extraIpPorts>[::]</extraIpPorts>
#      </ssh>
#      <tcp>
#       <enabled>true</enabled>
#       <ip>0.0.0.0</ip>
#       <port>2023</port>
#       <extraIpPorts>[::]</extraIpPorts>
#      </tcp>
#     </transport>
#     <extendedSessions>false</extendedSessions>
#     <sendDefaults>false</sendDefaults>
#     <idleTimeout>PT0S</idleTimeout>
#     <rpcErrors>inline</rpcErrors>
#     <maxBatchProcesses>unbounded</maxBatchProcesses>
#    </netconf>
#   </confdConfig>
#   <SNMP-COMMUNITY-MIB xmlns="http://tail-f.com/ns/mibs/SNMP-COMMUNITY-MIB/200308060000Z">
#    <snmpCommunityTable>
#     <snmpCommunityEntry>
#      <snmpCommunityIndex>public</snmpCommunityIndex>
#      <snmpCommunityName>public</snmpCommunityName>
#      <snmpCommunitySecurityName>public</snmpCommunitySecurityName>
#      <snmpCommunityContextEngineID>80:00:61:81:05:01</snmpCommunityContextEngineID>
#      <snmpCommunityContextName/>
#      <snmpCommunityTransportTag/>
#      <snmpCommunityStorageType>permanent</snmpCommunityStorageType>
#     </snmpCommunityEntry>
#    </snmpCommunityTable>
#   </SNMP-COMMUNITY-MIB>
#   <SNMP-NOTIFICATION-MIB xmlns="http://tail-f.com/ns/mibs/SNMP-NOTIFICATION-MIB/200210140000Z">
#    <snmpNotifyTable>
#     <snmpNotifyEntry>
#      <snmpNotifyName>std_v1_trap</snmpNotifyName>
#      <snmpNotifyTag>std_v1_trap</snmpNotifyTag>
#      <snmpNotifyType>trap</snmpNotifyType>
#      <snmpNotifyStorageType>nonVolatile</snmpNotifyStorageType>
#     </snmpNotifyEntry>
#     <snmpNotifyEntry>
#      <snmpNotifyName>std_v2_inform</snmpNotifyName>
#      <snmpNotifyTag>std_v2_inform</snmpNotifyTag>
#      <snmpNotifyType>inform</snmpNotifyType>
#      <snmpNotifyStorageType>nonVolatile</snmpNotifyStorageType>
#     </snmpNotifyEntry>
#     <snmpNotifyEntry>
#      <snmpNotifyName>std_v2_trap</snmpNotifyName>
#      <snmpNotifyTag>std_v2_trap</snmpNotifyTag>
#      <snmpNotifyType>trap</snmpNotifyType>
#      <snmpNotifyStorageType>nonVolatile</snmpNotifyStorageType>
#     </snmpNotifyEntry>
#     <snmpNotifyEntry>
#      <snmpNotifyName>std_v3_inform</snmpNotifyName>
#      <snmpNotifyTag>std_v3_inform</snmpNotifyTag>
#      <snmpNotifyType>inform</snmpNotifyType>
#      <snmpNotifyStorageType>nonVolatile</snmpNotifyStorageType>
#     </snmpNotifyEntry>
#     <snmpNotifyEntry>
#      <snmpNotifyName>std_v3_trap</snmpNotifyName>
#      <snmpNotifyTag>std_v3_trap</snmpNotifyTag>
#      <snmpNotifyType>trap</snmpNotifyType>
#      <snmpNotifyStorageType>nonVolatile</snmpNotifyStorageType>
#     </snmpNotifyEntry>
#    </snmpNotifyTable>
#   </SNMP-NOTIFICATION-MIB>
#   <SNMP-TARGET-MIB xmlns="http://tail-f.com/ns/mibs/SNMP-TARGET-MIB/200210140000Z">
#    <snmpTargetAddrTable>
#     <snmpTargetAddrEntry>
#      <snmpTargetAddrName>127.0.0.1 v1</snmpTargetAddrName>
#      <snmpTargetAddrTDomain>1.3.6.1.6.1.1</snmpTargetAddrTDomain>
#      <snmpTargetAddrTAddress>127.0.0.1.19.136</snmpTargetAddrTAddress>
#      <snmpTargetAddrTimeout>1500</snmpTargetAddrTimeout>
#      <snmpTargetAddrRetryCount>3</snmpTargetAddrRetryCount>
#      <snmpTargetAddrTagList>std_v1_trap std_trap std_v1_inform std_inform</snmpTargetAddrTagList>
#      <snmpTargetAddrParams>target_v1</snmpTargetAddrParams>
#      <snmpTargetAddrStorageType>nonVolatile</snmpTargetAddrStorageType>
#      <snmpTargetAddrEngineID/>
#      <snmpTargetAddrTMask/>
#      <snmpTargetAddrMMS>2048</snmpTargetAddrMMS>
#      <enabled>true</enabled>
#     </snmpTargetAddrEntry>
#     <snmpTargetAddrEntry>
#      <snmpTargetAddrName>127.0.0.1 v2</snmpTargetAddrName>
#      <snmpTargetAddrTDomain>1.3.6.1.6.1.1</snmpTargetAddrTDomain>
#      <snmpTargetAddrTAddress>127.0.0.1.23.112</snmpTargetAddrTAddress>
#      <snmpTargetAddrTimeout>1500</snmpTargetAddrTimeout>
#      <snmpTargetAddrRetryCount>3</snmpTargetAddrRetryCount>
#      <snmpTargetAddrTagList>std_v2_trap std_trap std_v2_inform std_inform</snmpTargetAddrTagList>
#      <snmpTargetAddrParams>target_v2</snmpTargetAddrParams>
#      <snmpTargetAddrStorageType>nonVolatile</snmpTargetAddrStorageType>
#      <snmpTargetAddrEngineID/>
#      <snmpTargetAddrTMask/>
#      <snmpTargetAddrMMS>2048</snmpTargetAddrMMS>
#      <enabled>true</enabled>
#     </snmpTargetAddrEntry>
#     <snmpTargetAddrEntry>
#      <snmpTargetAddrName>127.0.0.1 v3</snmpTargetAddrName>
#      <snmpTargetAddrTDomain>1.3.6.1.6.1.1</snmpTargetAddrTDomain>
#      <snmpTargetAddrTAddress>127.0.0.1.27.88</snmpTargetAddrTAddress>
#      <snmpTargetAddrTimeout>1500</snmpTargetAddrTimeout>
#      <snmpTargetAddrRetryCount>3</snmpTargetAddrRetryCount>
#      <snmpTargetAddrTagList>std_v3_trap std_trap</snmpTargetAddrTagList>
#      <snmpTargetAddrParams>trap_target_v3</snmpTargetAddrParams>
#      <snmpTargetAddrStorageType>nonVolatile</snmpTargetAddrStorageType>
#      <snmpTargetAddrEngineID/>
#      <snmpTargetAddrTMask/>
#      <snmpTargetAddrMMS>2048</snmpTargetAddrMMS>
#      <enabled>true</enabled>
#     </snmpTargetAddrEntry>
#     <snmpTargetAddrEntry>
#      <snmpTargetAddrName>127.0.0.1 v3.inform</snmpTargetAddrName>
#      <snmpTargetAddrTDomain>1.3.6.1.6.1.1</snmpTargetAddrTDomain>
#      <snmpTargetAddrTAddress>127.0.0.1.27.88</snmpTargetAddrTAddress>
#      <snmpTargetAddrTimeout>1500</snmpTargetAddrTimeout>
#      <snmpTargetAddrRetryCount>3</snmpTargetAddrRetryCount>
#      <snmpTargetAddrTagList>std_v3_inform std_inform</snmpTargetAddrTagList>
#      <snmpTargetAddrParams>inform_target_v3</snmpTargetAddrParams>
#      <snmpTargetAddrStorageType>nonVolatile</snmpTargetAddrStorageType>
#      <snmpTargetAddrEngineID>80:00:1f:88:04:74:65:73:74:69:6e:67</snmpTargetAddrEngineID>
#      <snmpTargetAddrTMask/>
#      <snmpTargetAddrMMS>2048</snmpTargetAddrMMS>
#      <enabled>true</enabled>
#     </snmpTargetAddrEntry>
#    </snmpTargetAddrTable>
#    <snmpTargetParamsTable>
#     <snmpTargetParamsEntry>
#      <snmpTargetParamsName>inform_target_v3</snmpTargetParamsName>
#      <snmpTargetParamsMPModel>3</snmpTargetParamsMPModel>
#      <snmpTargetParamsSecurityModel>3</snmpTargetParamsSecurityModel>
#      <snmpTargetParamsSecurityName>remote</snmpTargetParamsSecurityName>
#      <snmpTargetParamsSecurityLevel>noAuthNoPriv</snmpTargetParamsSecurityLevel>
#      <snmpTargetParamsStorageType>nonVolatile</snmpTargetParamsStorageType>
#     </snmpTargetParamsEntry>
#     <snmpTargetParamsEntry>
#      <snmpTargetParamsName>target_v1</snmpTargetParamsName>
#      <snmpTargetParamsMPModel>0</snmpTargetParamsMPModel>
#      <snmpTargetParamsSecurityModel>1</snmpTargetParamsSecurityModel>
#      <snmpTargetParamsSecurityName>public</snmpTargetParamsSecurityName>
#      <snmpTargetParamsSecurityLevel>noAuthNoPriv</snmpTargetParamsSecurityLevel>
#      <snmpTargetParamsStorageType>nonVolatile</snmpTargetParamsStorageType>
#     </snmpTargetParamsEntry>
#     <snmpTargetParamsEntry>
#      <snmpTargetParamsName>target_v2</snmpTargetParamsName>
#      <snmpTargetParamsMPModel>1</snmpTargetParamsMPModel>
#      <snmpTargetParamsSecurityModel>2</snmpTargetParamsSecurityModel>
#      <snmpTargetParamsSecurityName>public</snmpTargetParamsSecurityName>
#      <snmpTargetParamsSecurityLevel>noAuthNoPriv</snmpTargetParamsSecurityLevel>
#      <snmpTargetParamsStorageType>nonVolatile</snmpTargetParamsStorageType>
#     </snmpTargetParamsEntry>
#     <snmpTargetParamsEntry>
#      <snmpTargetParamsName>trap_target_v3</snmpTargetParamsName>
#      <snmpTargetParamsMPModel>3</snmpTargetParamsMPModel>
#      <snmpTargetParamsSecurityModel>3</snmpTargetParamsSecurityModel>
#      <snmpTargetParamsSecurityName>public</snmpTargetParamsSecurityName>
#      <snmpTargetParamsSecurityLevel>noAuthNoPriv</snmpTargetParamsSecurityLevel>
#      <snmpTargetParamsStorageType>nonVolatile</snmpTargetParamsStorageType>
#     </snmpTargetParamsEntry>
#    </snmpTargetParamsTable>
#   </SNMP-TARGET-MIB>
#   <SNMP-USER-BASED-SM-MIB xmlns="http://tail-f.com/ns/mibs/SNMP-USER-BASED-SM-MIB/200210160000Z">
#    <usmUserTable>
#     <usmUserEntry>
#      <usmUserEngineID>80:00:61:81:05:01</usmUserEngineID>
#      <usmUserName>initial</usmUserName>
#      <usmUserSecurityName>initial</usmUserSecurityName>
#      <usmUserAuthProtocol>1.3.6.1.6.3.10.1.1.1</usmUserAuthProtocol>
#      <usmUserPrivProtocol>1.3.6.1.6.3.10.1.2.1</usmUserPrivProtocol>
#      <usmUserStorageType>nonVolatile</usmUserStorageType>
#     </usmUserEntry>
#     <usmUserEntry>
#      <usmUserEngineID>80:00:61:81:05:01</usmUserEngineID>
#      <usmUserName>initial_auth</usmUserName>
#      <usmUserSecurityName>initial_auth</usmUserSecurityName>
#      <usmUserAuthProtocol>1.3.6.1.6.3.10.1.1.2</usmUserAuthProtocol>
#      <usmUserPrivProtocol>1.3.6.1.6.3.10.1.2.1</usmUserPrivProtocol>
#      <usmUserStorageType>nonVolatile</usmUserStorageType>
#      <usmUserAuthKey>10:2c:bd:65:e3:eb:e2:16:0d:63:db:23:73:f3:17:b2</usmUserAuthKey>
#     </usmUserEntry>
#     <usmUserEntry>
#      <usmUserEngineID>80:00:61:81:05:01</usmUserEngineID>
#      <usmUserName>initial_authPriv</usmUserName>
#      <usmUserSecurityName>initial_authPriv</usmUserSecurityName>
#      <usmUserAuthProtocol>1.3.6.1.6.3.10.1.1.2</usmUserAuthProtocol>
#      <usmUserPrivProtocol>1.3.6.1.6.3.10.1.2.2</usmUserPrivProtocol>
#      <usmUserStorageType>nonVolatile</usmUserStorageType>
#      <usmUserAuthKey>10:2c:bd:65:e3:eb:e2:16:0d:63:db:23:73:f3:17:b2</usmUserAuthKey>
#      <usmUserPrivKey>10:2c:bd:65:e3:eb:e2:16:0d:63:db:23:73:f3:17:b2</usmUserPrivKey>
#     </usmUserEntry>
#    </usmUserTable>
#   </SNMP-USER-BASED-SM-MIB>
#   <SNMP-VIEW-BASED-ACM-MIB xmlns="http://tail-f.com/ns/mibs/SNMP-VIEW-BASED-ACM-MIB/200210160000Z">
#    <vacmSecurityToGroupTable>
#     <vacmSecurityToGroupEntry>
#      <vacmSecurityModel>1</vacmSecurityModel>
#      <vacmSecurityName>public</vacmSecurityName>
#      <vacmGroupName>all-rights</vacmGroupName>
#      <vacmSecurityToGroupStorageType>nonVolatile</vacmSecurityToGroupStorageType>
#     </vacmSecurityToGroupEntry>
#     <vacmSecurityToGroupEntry>
#      <vacmSecurityModel>2</vacmSecurityModel>
#      <vacmSecurityName>public</vacmSecurityName>
#      <vacmGroupName>all-rights</vacmGroupName>
#      <vacmSecurityToGroupStorageType>nonVolatile</vacmSecurityToGroupStorageType>
#     </vacmSecurityToGroupEntry>
#     <vacmSecurityToGroupEntry>
#      <vacmSecurityModel>3</vacmSecurityModel>
#      <vacmSecurityName>initial</vacmSecurityName>
#      <vacmGroupName>initial</vacmGroupName>
#      <vacmSecurityToGroupStorageType>nonVolatile</vacmSecurityToGroupStorageType>
#     </vacmSecurityToGroupEntry>
#     <vacmSecurityToGroupEntry>
#      <vacmSecurityModel>3</vacmSecurityModel>
#      <vacmSecurityName>initial_auth</vacmSecurityName>
#      <vacmGroupName>initial</vacmGroupName>
#      <vacmSecurityToGroupStorageType>nonVolatile</vacmSecurityToGroupStorageType>
#     </vacmSecurityToGroupEntry>
#     <vacmSecurityToGroupEntry>
#      <vacmSecurityModel>3</vacmSecurityModel>
#      <vacmSecurityName>initial_authPriv</vacmSecurityName>
#      <vacmGroupName>initial</vacmGroupName>
#      <vacmSecurityToGroupStorageType>nonVolatile</vacmSecurityToGroupStorageType>
#     </vacmSecurityToGroupEntry>
#    </vacmSecurityToGroupTable>
#    <vacmAccessTable>
#     <vacmAccessEntry>
#      <vacmGroupName>initial</vacmGroupName>
#      <vacmAccessContextPrefix/>
#      <vacmAccessSecurityModel>3</vacmAccessSecurityModel>
#      <vacmAccessSecurityLevel>noAuthNoPriv</vacmAccessSecurityLevel>
#      <vacmAccessContextMatch>exact</vacmAccessContextMatch>
#      <vacmAccessReadViewName>internet</vacmAccessReadViewName>
#      <vacmAccessWriteViewName>internet</vacmAccessWriteViewName>
#      <vacmAccessNotifyViewName>internet</vacmAccessNotifyViewName>
#      <vacmAccessStorageType>nonVolatile</vacmAccessStorageType>
#     </vacmAccessEntry>
#     <vacmAccessEntry>
#      <vacmGroupName>initial</vacmGroupName>
#      <vacmAccessContextPrefix/>
#      <vacmAccessSecurityModel>3</vacmAccessSecurityModel>
#      <vacmAccessSecurityLevel>authNoPriv</vacmAccessSecurityLevel>
#      <vacmAccessContextMatch>exact</vacmAccessContextMatch>
#      <vacmAccessReadViewName>internet</vacmAccessReadViewName>
#      <vacmAccessWriteViewName>internet</vacmAccessWriteViewName>
#      <vacmAccessNotifyViewName>internet</vacmAccessNotifyViewName>
#      <vacmAccessStorageType>nonVolatile</vacmAccessStorageType>
#     </vacmAccessEntry>
#     <vacmAccessEntry>
#      <vacmGroupName>initial</vacmGroupName>
#      <vacmAccessContextPrefix/>
#      <vacmAccessSecurityModel>3</vacmAccessSecurityModel>
#      <vacmAccessSecurityLevel>authPriv</vacmAccessSecurityLevel>
#      <vacmAccessContextMatch>exact</vacmAccessContextMatch>
#      <vacmAccessReadViewName>internet</vacmAccessReadViewName>
#      <vacmAccessWriteViewName>internet</vacmAccessWriteViewName>
#      <vacmAccessNotifyViewName>internet</vacmAccessNotifyViewName>
#      <vacmAccessStorageType>nonVolatile</vacmAccessStorageType>
#     </vacmAccessEntry>
#     <vacmAccessEntry>
#      <vacmGroupName>all-rights</vacmGroupName>
#      <vacmAccessContextPrefix/>
#      <vacmAccessSecurityModel>0</vacmAccessSecurityModel>
#      <vacmAccessSecurityLevel>noAuthNoPriv</vacmAccessSecurityLevel>
#      <vacmAccessContextMatch>exact</vacmAccessContextMatch>
#      <vacmAccessReadViewName>internet</vacmAccessReadViewName>
#      <vacmAccessWriteViewName>internet</vacmAccessWriteViewName>
#      <vacmAccessNotifyViewName>internet</vacmAccessNotifyViewName>
#      <vacmAccessStorageType>nonVolatile</vacmAccessStorageType>
#     </vacmAccessEntry>
#    </vacmAccessTable>
#    <vacmViewTreeFamilyTable>
#     <vacmViewTreeFamilyEntry>
#      <vacmViewTreeFamilyViewName>internet</vacmViewTreeFamilyViewName>
#      <vacmViewTreeFamilySubtree>1.3.6.1</vacmViewTreeFamilySubtree>
#      <vacmViewTreeFamilyMask/>
#      <vacmViewTreeFamilyType>included</vacmViewTreeFamilyType>
#      <vacmViewTreeFamilyStorageType>nonVolatile</vacmViewTreeFamilyStorageType>
#     </vacmViewTreeFamilyEntry>
#    </vacmViewTreeFamilyTable>
#   </SNMP-VIEW-BASED-ACM-MIB>
#   <SNMPv2-MIB xmlns="http://tail-f.com/ns/mibs/SNMPv2-MIB/200210160000Z">
#    <system>
#     <sysContact/>
#     <sysName/>
#     <sysLocation/>
#    </system>
#    <snmp>
#     <snmpEnableAuthenTraps>disabled</snmpEnableAuthenTraps>
#    </snmp>
#   </SNMPv2-MIB>
#   <fpd xmlns="http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-fpd-infra-cli-fpd">
#    <config>
#     <auto-upgrade>disable</auto-upgrade>
#    </config>
#   </fpd>
#   <sdr-config xmlns="http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-sdr-mgr">
#    <sdr>
#     <name>default-sdr</name>
#     <resources>
#      <card-type>
#       <type>RP</type>
#       <vm-memory>2</vm-memory>
#       <vm-cpu>1</vm-cpu>
#      </card-type>
#      <card-type>
#       <type>LC</type>
#       <vm-memory>1</vm-memory>
#       <vm-cpu>1</vm-cpu>
#      </card-type>
#     </resources>
#     <location>
#      <node-location>all</node-location>
#     </location>
#    </sdr>
#   </sdr-config>
#   <private-sdr xmlns="http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-sdr-mgr">
#    <sdr-name>
#     <name>default-sdr</name>
#     <id>2</id>
#     <lead_rack0>0</lead_rack0>
#     <lead_rack1>0</lead_rack1>
#     <pairing>
#      <num>0</num>
#      <second_exist>false</second_exist>
#      <rp1_rack>0</rp1_rack>
#      <rp1_slot>0</rp1_slot>
#     </pairing>
#    </sdr-name>
#   </private-sdr>
#   <service xmlns="http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-services">
#    <cli>
#     <interactive>
#      <enabled>true</enabled>
#     </interactive>
#    </cli>
#   </service>
#   <interfaces xmlns="http://openconfig.net/yang/interfaces">
#    <interface>
#     <name>MgmtEth0/RP0/CPU0/0</name>
#     <config>
#      <name>MgmtEth0/RP0/CPU0/0</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>true</enabled>
#      <description>*** MANAGEMENT INTERFACE ***</description>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#     <subinterfaces>
#      <subinterface>
#       <index>0</index>
#      </subinterface>
#     </subinterfaces>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/0</name>
#     <config>
#      <name>GigabitEthernet0/0/0/0</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/1</name>
#     <config>
#      <name>GigabitEthernet0/0/0/1</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/2</name>
#     <config>
#      <name>GigabitEthernet0/0/0/2</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/3</name>
#     <config>
#      <name>GigabitEthernet0/0/0/3</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/4</name>
#     <config>
#      <name>GigabitEthernet0/0/0/4</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#   </interfaces>
#   <lacp xmlns="http://openconfig.net/yang/lacp">
#    <interfaces>
#     <interface>
#      <name>MgmtEth0/RP0/CPU0/0</name>
#      <config>
#       <name>MgmtEth0/RP0/CPU0/0</name>
#      </config>
#     </interface>
#     <interface>
#      <name>GigabitEthernet0/0/0/0</name>
#      <config>
#       <name>GigabitEthernet0/0/0/0</name>
#      </config>
#     </interface>
#     <interface>
#      <name>GigabitEthernet0/0/0/1</name>
#      <config>
#       <name>GigabitEthernet0/0/0/1</name>
#      </config>
#     </interface>
#     <interface>
#      <name>GigabitEthernet0/0/0/2</name>
#      <config>
#       <name>GigabitEthernet0/0/0/2</name>
#      </config>
#     </interface>
#     <interface>
#      <name>GigabitEthernet0/0/0/3</name>
#      <config>
#       <name>GigabitEthernet0/0/0/3</name>
#      </config>
#     </interface>
#     <interface>
#      <name>GigabitEthernet0/0/0/4</name>
#      <config>
#       <name>GigabitEthernet0/0/0/4</name>
#      </config>
#     </interface>
#    </interfaces>
#   </lacp>
#   <network-instances xmlns="http://openconfig.net/yang/network-instance">
#    <network-instance>
#     <name>default</name>
#     <config>
#      <name>default</name>
#     </config>
#     <protocols>
#      <protocol>
#       <identifier xmlns:idx="http://openconfig.net/yang/policy-types">idx:STATIC</identifier>
#       <name>DEFAULT</name>
#       <config>
#        <identifier xmlns:idx="http://openconfig.net/yang/policy-types">idx:STATIC</identifier>
#        <name>DEFAULT</name>
#       </config>
#       <static-routes>
#        <static>
#         <prefix>0.0.0.0/0</prefix>
#         <config>
#          <prefix>0.0.0.0/0</prefix>
#         </config>
#         <next-hops>
#          <next-hop>
#           <index>**192.168.122.1**</index>
#           <config>
#            <index>**192.168.122.1**</index>
#            <next-hop>192.168.122.1</next-hop>
#           </config>
#          </next-hop>
#         </next-hops>
#        </static>
#       </static-routes>
#      </protocol>
#     </protocols>
#    </network-instance>
#   </network-instances>
#  </data>

# %%
print(running_dict)
# Out:
# OrderedDict([('data', OrderedDict([('@xmlns', 'urn:ietf:params:xml:ns:netconf:base:1.0'), ('@xmlns:nc', 'urn:ietf:params:xml:ns:netconf:base:1.0'), ('host-names', OrderedDict([('@xmlns', 'http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-cfg'), ('host-name', 'r1')])), ('call-home', OrderedDict([('@xmlns', 'http://cisco.com/ns/yang/Cisco-IOS-XR-call-home-cfg'), ('active', None), ('contact-smart-licensing', 'true'), ('profiles', OrderedDict([('profile', OrderedDict([('profile-name', 'CiscoTAC-1'), ('create', None), ('active', None), ('methods', OrderedDict([('method', [OrderedDict([('method', 'email'), ('enable', 'false')]), OrderedDict([('method', 'http'), ('enable', 'true')])])]))]))]))])), ('interface-configurations', OrderedDict([('@xmlns', 'http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-cfg'), ('interface-configuration', [OrderedDict([('active', 'act'), ('interface-name', 'MgmtEth0/RP0/CPU0/0'), ('description', '*** MANAGEMENT INTERFACE ***'), ('ipv4-network', OrderedDict([('@xmlns', 'http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-cfg'), ('addresses', OrderedDict([('dhcp', OrderedDict([('enabled', None), ('pattern', 'MgmtEth0_RP0_CPU0_0')]))]))]))]), OrderedDict([('active', 'act'), ('interface-name', 'GigabitEthernet0/0/0/0'), ('shutdown', None)]), OrderedDict([('active', 'act'), ('interface-name', 'GigabitEthernet0/0/0/1'), ('shutdown', None)]), OrderedDict([('active', 'act'), ('interface-name', 'GigabitEthernet0/0/0/2'), ('shutdown', None)]), OrderedDict([('active', 'act'), ('interface-name', 'GigabitEthernet0/0/0/3'), ('shutdown', None)]), OrderedDict([('active', 'act'), ('interface-name', 'GigabitEthernet0/0/0/4'), ('shutdown', None)])])])), ('banners', OrderedDict([('@xmlns', 'http://cisco.com/ns/yang/Cisco-IOS-XR-infra-infra-cfg'), ('banner', OrderedDict([('banner-name', 'motd'), ('banner-text', ';\n--------------------------------------------------------------------------\n  Router 1 (Cisco IOS XR Sandbox)\n--------------------------------------------------------------------------\n;')]))])), ('aaa', [OrderedDict([('@xmlns', 'http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-cfg'), ('usernames', OrderedDict([('@xmlns', 'http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg'), ('username', OrderedDict([('ordering-index', '0'), ('name', 'admin'), ('usergroup-under-usernames', OrderedDict([('usergroup-under-username', [OrderedDict([('name', 'root-lr')]), OrderedDict([('name', 'cisco-support')])])])), ('secret', '$1$A4C9$oaNorr6BXDruE4gDd086L.')]))]))]), OrderedDict([('@xmlns', 'http://tail-f.com/ns/aaa/1.1'), ('authentication', OrderedDict([('users', OrderedDict([('user', OrderedDict([('name', 'admin'), ('uid', '9000'), ('gid', '100'), ('password', '$1$1hD9$xG4Q4FDr.ptf9nyEHLDkI1'), ('ssh_keydir', '/var/confd/homes/admin/.ssh'), ('homedir', '/var/confd/homes/admin')]))])), ('groups', OrderedDict([('group', [OrderedDict([('name', 'aaa-r'), ('gid', '100'), ('users', '%%__system_user__%%')]), OrderedDict([('name', 'admin-r'), ('gid', '100'), ('users', '%%__system_user__%%')]), OrderedDict([('name', 'root-system'), ('gid', '100'), ('users', '%%__system_user__%% admin')])])]))])), ('authorization', OrderedDict([('cmdrules', OrderedDict([('cmdrule', [OrderedDict([('index', '1'), ('context', '*'), ('command', '*'), ('group', 'root-system'), ('ops', 'rx'), ('action', 'accept')]), OrderedDict([('index', '2'), ('context', '*'), ('command', 'show running-config aaa'), ('group', 'aaa-r'), ('ops', 'rx'), ('action', 'accept')]), OrderedDict([('index', '3'), ('context', '*'), ('command', 'show tech-support aaa'), ('group', 'aaa-r'), ('ops', 'rx'), ('action', 'accept')]), OrderedDict([('index', '4'), ('context', '*'), ('command', 'show aaa'), ('group', 'aaa-r'), ('ops', 'rx'), ('action', 'accept')]), OrderedDict([('index', '5'), ('context', '*'), ('command', 'show'), ('group', 'admin-r'), ('ops', 'rx'), ('action', 'accept')])])])), ('datarules', OrderedDict([('datarule', [OrderedDict([('index', '1'), ('namespace', '*'), ('context', '*'), ('keypat ...

# %%
print(running_json)
# Out:
# {
#     "data": {
#         "@xmlns": "urn:ietf:params:xml:ns:netconf:base:1.0",
#         "@xmlns:nc": "urn:ietf:params:xml:ns:netconf:base:1.0",
#         "host-names": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-cfg",
#             "host-name": "r1"
#         },
#         "call-home": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-call-home-cfg",
#             "active": null,
#             "contact-smart-licensing": "true",
#             "profiles": {
#                 "profile": {
#                     "profile-name": "CiscoTAC-1",
#                     "create": null,
#                     "active": null,
#                     "methods": {
#                         "method": [
#                             {
#                                 "method": "email",
#                                 "enable": "false"
#                             },
#                             {
#                                 "method": "http",
#                                 "enable": "true"
#                             }
#                         ]
#                     }
#                 }
#             }
#         },
#         "interface-configurations": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-cfg",
#             "interface-configuration": [
#                 {
#                     "active": "act",
#                     "interface-name": "MgmtEth0/RP0/CPU0/0",
#                     "description": "*** MANAGEMENT INTERFACE ***",
#                     "ipv4-network": {
#                         "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-cfg",
#                         "addresses": {
#                             "dhcp": {
#                                 "enabled": null,
#                                 "pattern": "MgmtEth0_RP0_CPU0_0"
#                             }
#                         }
#                     }
#                 },
#                 {
#                     "active": "act",
#                     "interface-name": "GigabitEthernet0/0/0/0",
#                     "shutdown": null
#                 },
#                 {
#                     "active": "act",
#                     "interface-name": "GigabitEthernet0/0/0/1",
#                     "shutdown": null
#                 },
#                 {
#                     "active": "act",
#                     "interface-name": "GigabitEthernet0/0/0/2",
#                     "shutdown": null
#                 },
#                 {
#                     "active": "act",
#                     "interface-name": "GigabitEthernet0/0/0/3",
#                     "shutdown": null
#                 },
#                 {
#                     "active": "act",
#                     "interface-name": "GigabitEthernet0/0/0/4",
#                     "shutdown": null
#                 }
#             ]
#         },
#         "banners": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-infra-infra-cfg",
#             "banner": {
#                 "banner-name": "motd",
#                 "banner-text": ";\n--------------------------------------------------------------------------\n  Router 1 (Cisco IOS XR Sandbox)\n--------------------------------------------------------------------------\n;"
#             }
#         },
#         "aaa": [
#             {
#                 "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-cfg",
#                 "usernames": {
#                     "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg",
#                     "username": {
#                         "ordering-index": "0",
#                         "name": "admin",
#                         "usergroup-under-usernames": {
#                             "usergroup-under-username": [
#                                 {
#                                     "name": "root-lr"
#                                 },
#                                 {
#                                     "name": "cisco-support"
#                                 }
#                             ]
#                         },
#                         "secret": "$1$A4C9$oaNorr6BXDruE4gDd086L."
#                     }
#                 }
#             },
#             {
#                 "@xmlns": "http://tail-f.com/ns/aaa/1.1",
#                 "authentication": {
#                     "users": {
#                         "user": {
#                             "name": "admin",
#                             "uid": "9000",
#                             "gid": "100",
#                             "password": "$1$1hD9$xG4Q4FDr.ptf9nyEHLDkI1",
#                             "ssh_keydir": "/var/confd/homes/admin/.ssh",
#                             "homedir": "/var/confd/homes/admin"
#                         }
#                     },
#                     "groups": {
#                         "group": [
#                             {
#                                 "name": "aaa-r",
#                                 "gid": "100",
#                                 "users": "%%__system_user__%%"
#                             },
#                             {
#                                 "name": "admin-r",
#                                 "gid": "100",
#                                 "users": "%%__system_user__%%"
#                             },
#                             {
#                                 "name": "root-system",
#                                 "gid": "100",
#                                 "users": "%%__system_user__%% admin"
#                             }
#                         ]
#                     }
#                 },
#                 "authorization": {
#                     "cmdrules": {
#                         "cmdrule": [
#                             {
#                                 "index": "1",
#                                 "context": "*",
#                                 "command": "*",
#                                 "group": "root-system",
#                                 "ops": "rx",
#                                 "action": "accept"
#                             },
#                             {
#                                 "index": "2",
#                                 "context": "*",
#                                 "command": "show running-config aaa",
#                                 "group": "aaa-r",
#                                 "ops": "rx",
#                                 "action": "accept"
#                             },
#                             {
#                                 "index": "3",
#                                 "context": "*",
#                                 "command": "show tech-support aaa",
#                                 "group": "aaa-r",
#                                 "ops": "rx",
#                                 "action": "accept"
#                             },
#                             {
#                                 "index": "4",
#                                 "context": "*",
#                                 "command": "show aaa",
#                                 "group": "aaa-r",
#                                 "ops": "rx",
#                                 "action": "accept"
#                             },
#                             {
#                                 "index": "5",
#                                 "context": "*",
#                                 "command": "show",
#                                 "group": "admin-r",
#                                 "ops": "rx",
#                                 "action": "accept"
#                             }
#                         ]
#                     },
#                     "datarules": {
#                         "datarule": [
#                             {
#                                 "index": "1",
#                                 "namespace": "*",
#                                 "context": "*",
#                                 "keypath": "*",
#                                 "group": "root-system",
#                                 "ops": "rwx",
#                                 "action": "accept"
#                             },
#                             {
#                                 "index": "2",
#                                 "namespace": "*",
#                                 "context": "*",
#                                 "keypath": "/aaa",
#                                 "group": "aaa-r",
#                                 "ops": "r",
#                                 "action": "accept"
#                             },
#                             {
#                                 "index": "3",
#                                 "namespace": "*",
#                                 "context": "*",
#                                 "keypath": "/aaa",
#                                 "group": "admin-r",
#                                 "ops": "rwx",
#                                 "action": "reject"
#                             },
#                             {
#                                 "index": "4",
#                                 "namespace": "*",
#                                 "context": "*",
#                                 "keypath": "/",
#                                 "group": "admin-r",
#                                 "ops": "r",
#                                 "action": "accept"
#                             }
#                         ]
#                     }
#                 }
#             }
#         ],
#         "vty": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-tty-vty-cfg",
#             "vty-pools": {
#                 "vty-pool": {
#                     "pool-name": "default",
#                     "first-vty": "0",
#                     "last-vty": "4",
#                     "line-template": "VTY-TEMPLATE"
#                 }
#             }
#         },
#         "ssh": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-ssh-cfg",
#             "server": {
#                 "v2": null,
#                 "netconf-vrf-table": {
#                     "vrf": {
#                         "vrf-name": "default",
#                         "enable": null
#                     }
#                 }
#             }
#         },
#         "netconf-yang": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-man-netconf-cfg",
#             "agent": {
#                 "ssh": {
#                     "enable": null
#                 }
#             }
#         },
#         "tty": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-tty-server-cfg",
#             "tty-lines": {
#                 "tty-line": {
#                     "name": "console",
#                     "exec": {
#                         "time-stamp": "false",
#                         "timeout": {
#                             "minutes": "0",
#                             "seconds": "0"
#                         }
#                     }
#                 }
#             }
#         },
#         "syslog-service": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-infra-syslog-cfg",
#             "timestamps": {
#                 "log": {
#                     "log-datetime": {
#                         "log-datetime-value": {
#                             "msec": "enable"
#                         }
#                     }
#                 },
#                 "debug": {
#                     "debug-datetime": {
#                         "datetime-value": {
#                             "msec": "enable"
#                         }
#                     }
#                 }
#             }
#         },
#         "router-static": {
#             "@xmlns": "http://cisco.com/ns/yang/Cisco-IOS-XR-ip-static-cfg",
#             "default-vrf": {
#                 "address-family": {
#                     "vrfipv4": {
#                         "vrf-unicast": {
#                             "vrf-prefixes": {
#                                 "vrf-prefix": {
#                                     "prefix": "0.0.0.0",
#                                     "prefix-length": "0",
#                                     "vrf-route": {
#                                         "vrf-next-hop-table": {
#                                             "vrf-next-hop-next-hop-address": {
#                                                 "next-hop-address": "192.168.122.1"
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#                     }
#                 }
#             }
#         },
#         "confdConfig": {
#             "@xmlns": "http://tail-f.com/ns/confd_dyncfg/1.0",
#             "hideGroup": {
#                 "name": "advanced-grp",
#                 "password": null
#             },
#             "encryptedStrings": {
#                 "DES3CBC": {
#                     "key1": "0123456789ABCDEF",
#                     "key2": "0123456789ABCDEF",
#                     "key3": "0123456789ABCDEF",
#                     "initVector": "0123456789ABCDEF"
#                 },
#                 "AESCFB128": {
#                     "key": "0123456789ABCDEF0123456789ABCDEF",
#                     "initVector": "0123456789ABCDEF0123456789ABCDEF"
#                 }
#             },
#             "logs": {
#                 "syslogConfig": {
#                     "version": "bsd",
#                     "facility": "daemon",
#                     "udp": {
#                         "enabled": "false",
#                         "host": "syslogsrv.example.com",
#                         "port": "514"
#                     }
#                 },
#                 "confdLog": {
#                     "enabled": "true",
#                     "file": {
#                         "enabled": "true",
#                         "name": "/var/log/confd_daemon.log"
#                     },
#                     "syslog": {
#                         "enabled": "false"
#                     }
#                 },
#                 "developerLog": {
#                     "enabled": "true",
#                     "file": {
#                         "enabled": "true",
#                         "name": "/var/log/confd_developer.log"
#                     },
#                     "syslog": {
#                         "enabled": "false"
#                     }
#                 },
#                 "developerLogLevel": "trace",
#                 "auditLog": {
#                     "enabled": "true",
#                     "file": {
#                         "enabled": "true",
#                         "name": "/var/log/confd_audit.log"
#                     },
#                     "syslog": {
#                         "enabled": "false"
#                     }
#                 },
#                 "auditLogCommit": "false",
#                 "netconfLog": {
#                     "enabled": "true",
#                     "file": {
#                         "enabled": "true",
#                         "name": "/var/log/confd_netconf.log"
#                     },
#                     "syslog": {
#                         "enabled": "false"
#                     }
#                 },
#                 "snmpLog": {
#                     "enabled": "true",
#                     "file": {
#                         "enabled": "true",
#                         "name": "/var/log/confd_snmp.log"
#                     },
#                     "syslog": {
#                         "enabled": "false"
#                     }
#                 },
#                 "webuiAccessLog": {
#                     "enabled": "false",
#                     "dir": "/var/log/confd_webui.log"
#                 },
#                 "netconfTraceLog": {
#                     "enabled": "false",
#                     "filename": "/var/log/confd_netconf_trace.log",
#                     "format": "pretty"
#                 },
#                 "errorLog": {
#                     "enabled": "true",
#                     "filename": "/var/log/confd_error.log",
#                     "maxSize": "S1M"
#                 }
#             },
#             "cli": {
#                 "enabled": "true",
#                 "modeNameStyle": "short",
#                 "allowOverwriteOnCopy": "false",
#                 "inheritPaginate": "true",
#                 "safeScriptExecution": "true",
#                 "exitConfigModeOnCtrlC": "false",
#                 "execNavigationCmds": "false",
#                 "allowOldStyleModeCmds": "false",
#                 "mixedMode": "false",
#                 "topLevelCmdsInSubMode": "true",
#                 "completionShowOldVal": "true",
#                 "reportInvalidCompletionInput": "true",
#                 "useShortEnabled": "true",
#                 "smartRenameFiltering": "true",
#                 "allowParenQuotes": "false",
#                 "singleElemPattern": "true",
#                 "multiPatternOperation": "any",
#                 "sortSubmodeCmds": "true",
#                 "sortLocalCmds": "true",
#                 "displayEmptyConfigContainers": "true",
#                 "whoShowMode": "true",
#                 "whoHistoryDateTimeFormat": "short",
#                 "editWrapMode": "wrap",
#                 "supportQuotedEOL": "true",
#                 "allowWildcard": "true",
#                 "allowAllAsWildcard": "false",
#                 "allowRangeExpression": "true",
#                 "addExtraTableSpacing": "false",
#                 "suppressRangeKeyword": "false",
#                 "tableLabel": "false",
#                 "tableLookAhead": "50",
#                 "showTableLabelsIfMultiple": "false",
#                 "defaultTableBehavior": "dynamic",
#                 "allowTableOverflow": "false",
#                 "tableOverflowTruncate": "false",
#                 "allowTableCellWrap": "false",
#                 "showAllNs": "false",
#                 "leafPrompting": "true",
#                 "auditLogMode": "all",
#                 "transactions": "true",
#                 "transactionCtrlCmds": "false",
#                 "style": "c",
#                 "completionShowMax": "2000",
#                 "rollbackMax": "1000",
#                 "rollbackNumbering": "fixed",
#                 "rollbackNumberingInitial": "10000",
#                 "showDefaults": "false",
#                 "reallocateOperTrans": "false",
#                 "quickSshTeardown": "false",
#                 "cAlignLeafValues": "true",
#                 "defaultPrefix": null,
#                 "jWarningPrefix": "Warning:",
#                 "jAbortedPrefix": "Aborted:",
#                 "jErrorPrefix": "Error:",
#                 "cWarningPrefix": "Warning:",
#                 "cAbortedPrefix": "Aborted:",
#                 "cErrorPrefix": "Error:",
#                 "invalidDataString": "--ERROR--",
#                 "showKeyName": "true",
#                 "commitRetryTimeout": "PT15S",
#                 "timezone": "local",
#                 "utcOffset": "0",
#                 "oldDetailsArg": "false",
#                 "withDefaults": "false",
#                 "trimDefaultShow": "false",
#                 "trimDefaultSave": "false",
#                 "banner": null,
#                 "bannerFile": null,
#                 "prompt1": "\\u@\\h\\M>",
#                 "prompt2": "\\u@\\h\\M%",
#                 "cPrompt1": "\\H#",
#                 "cPrompt2": "\\H(\\m)#",
#                 "cStylePromptInJStyle": "false",
#                 "promptHostnameDelimiter": ".",
#                 "asyncPromptRefresh": "true",
#                 "showLogDirectory": "/var/log/",
#                 "idleTimeout": "PT10M",
#                 "disableIdleTimeoutOnCmd": "true",
#                 "commandTimeout": "infinity",
#                 "spaceCompletion": {
#                     "enabled": "false"
#                 },
#                 "timestamp": {
#                     "enabled": "true"
#                 },
#                 "autoWizard": {
#                     "enabled": "false"
#                 },
#                 "ssh": {
#                     "enabled": "false",
#                     "ip": "0.0.0.0",
#                     "port": "2024",
#                     "extraIpPorts": "[::]",
#                     "banner": null,
#                     "bannerFile": null
#                 },
#                 "commitMessage": "true",
#                 "commitMessageFormat": "\\nSystem message at $(time)...\\nCommit performed by $(user) via $(proto) using $(ctx).\\n",
#                 "jShowCR": "false",
#                 "showPipe": "true",
#                 "showPipeConfig": "false",
#                 "disablePipe": "false",
#                 "disablePipeConfig": "false",
#                 "pipeHelpMode": "always",
#                 "jAllowDeleteAll": "true",
#                 "cSilentNo": "true",
#                 "noFollowIncompleteCommand": "false",
#                 "cRestrictiveNo": "true",
#                 "prioritizeSubmodeCmds": "true",
#                 "cExtendedCmdSearch": "true",
#                 "enterSubmodeOnLeaf": "false",
#                 "jExtendedShow": "true",
#                 "jShowUnset": "false",
#                 "jShowUnsetText": "UNSET",
#                 "jStatusFormat": "[$(status)][$(time)]\\n",
#                 "cModeExitFormat": "!",
#                 "forcedExitFormat": "\\nYou are forced out of configure mode by $(sender).\\n",
#                 "showSubsystemMessages": "false",
#                 "ignoreSubsystemFailures": "true",
#                 "showEmptyContainers": "false",
#                 "showTags": "true",
#                 "showAnnotations": "true",
#                 "jShowTableRecursive": "false",
#                 "cPrivate": "false",
#                 "cTab": "false",
#                 "cTabInfo": "false",
#                 "tabExtend": "true",
#                 "cHelp": "true",
#                 "restrictedFileAccess": "false",
#                 "hideDotFiles": "false",
#                 "restrictedFileRegexp": null,
#                 "historyRemoveDuplicates": "false",
#                 "historyMaxSize": "1000",
#                 "messageMaxSize": "10000",
#                 "mapActions": "oper",
#                 "compactTable": "true",
#                 "compactShow": "false",
#                 "compactStatsShow": "false",
#                 "prettifyStatsName": "false",
#                 "showCommitProgress": "false",
#                 "commitActivityClock": "false",
#                 "confirmUncommitedOnExit": "prompt",
#                 "reconfirmHidden": "false",
#                 "dequoteHidden": "false",
#                 "enumKeyInfo": "false",
#                 "columnStats": "false",
#                 "allowAbbrevCmds": "true",
#                 "allowAbbrevCmdsOnLoad": "true",
#                 "allowAbbrevKeys": "false",
#                 "allowAbbrevParamNames": "true",
#                 "allowAbbrevEnums": "true",
#                 "allowCaseInsensitiveEnums": "true",
#                 "strictRefsOnLoad": "false",
#                 "stopLoadOnError": "true",
#                 "autocommitLoad": "false",
#                 "enableLoadMerge": "true",
#                 "loadActivityClock": "false",
#                 "instanceDescription": "true",
#                 "addErrorPrefixSuffix": "true",
#                 "compListCompact": "false",
#                 "completionListLine": "false",
#                 "infoOnMatch": "true",
#                 "enableDisplayLevel": "false",
#                 "defaultDisplayLevel": "99999999",
#                 "enableDisplayGroups": "true",
#                 "unifiedHistory": "false",
#                 "modeInfoInAAA": "false",
#                 "cmdAAAForAutowizard": "false",
#                 "quoteStyle": "backslash",
#                 "laxBarQuoting": "false",
#                 "expandAliasEscape": "false",
#                 "docWrap": "true",
#                 "infoOnTab": "true",
#                 "infoOnSpace": "true",
#                 "newLogout": "true",
#                 "newInsert": "true",
#                 "messageFormat": "\\nMessage from $(sender) at $(time)...\\n$(message)\\nEOF\\n",
#                 "messageWordWrap": "false",
#                 "messageQueueSize": "10",
#                 "promptEnumLimit": "4",
#                 "caseInsensitive": "true",
#                 "caseInsensitiveKeys": "true",
#                 "ignoreLeadingWhitespace": "false",
#                 "indentTemplates": "false",
#                 "wrapInfo": "true",
#                 "wrapPrompt": "false",
#                 "sortShowElems": "true",
#                 "showMatchBeforePossible": "false",
#                 "possibleCompletionsFormat": "Possible completions:",
#                 "matchCompletionsFormat": "Possible match completions:",
#                 "noMatchCompletionsFormat": null,
#                 "showDescription": "true",
#                 "explicitSetCreate": "false"
#             },
#             "snmpAgent": {
#                 "enabled": "false",
#                 "ip": "0.0.0.0",
#                 "port": "161",
#                 "extraIpPorts": "[::]",
#                 "dscp": "0",
#                 "mibs": {
#                     "file": [
#                         "/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/CISCO-ENTITY-FRU-CONTROL-MIB.bin",
#                         "/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/CISCO-ENTITY-SENSOR-MIB.bin",
#                         "/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/ENTITY-MIB.bin",
#                         "/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/ENTITY-STATE-MIB.bin",
#                         "/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/ENTITY-STATE-TC-MIB.bin",
#                         "/opt/cisco/calvados/confd/lib/confd/priv/snmp/mibs/INET-ADDRESS-MIB.bin",
#                         "SNMP-COMMUNITY-MIB.bin",
#                         "SNMP-NOTIFICATION-MIB.bin",
#                         "SNMP-TARGET-MIB.bin",
#                         "SNMP-USER-BASED-SM-MIB.bin",
#                         "SNMP-VIEW-BASED-ACM-MIB.bin"
#                     ],
#                     "fromLoadPath": "false"
#                 },
#                 "temporaryStorageTime": "300",
#                 "snmpVersions": {
#                     "v1": "true",
#                     "v2c": "true",
#                     "v3": "false"
#                 },
#                 "snmpEngine": {
#                     "snmpEngineID": "80:00:61:81:05:01",
#                     "snmpEngineMaxMessageSize": "50000"
#                 },
#                 "authenticationFailureNotifyName": null,
#                 "system": {
#                     "sysDescr": "Cisco Calvados SNMP agent",
#                     "sysObjectID": "1.3.6.1.4.1.24961",
#                     "sysServices": "72",
#                     "sysORTable": null
#                 }
#             },
#             "netconf": {
#                 "enabled": "true",
#                 "transport": {
#                     "ssh": {
#                         "enabled": "true",
#                         "ip": "0.0.0.0",
#                         "port": "2022",
#                         "extraIpPorts": "[::]"
#                     },
#                     "tcp": {
#                         "enabled": "true",
#                         "ip": "0.0.0.0",
#                         "port": "2023",
#                         "extraIpPorts": "[::]"
#                     }
#                 },
#                 "extendedSessions": "false",
#                 "sendDefaults": "false",
#                 "idleTimeout": "PT0S",
#                 "rpcErrors": "inline",
#                 "maxBatchProcesses": "unbounded"
#             }
#         },
#         "SNMP-COMMUNITY-MIB": {
#             "@xmlns": "http://tail-f.com/ns/mibs/SNMP-COMMUNITY-MIB/200308060000Z",
#             "snmpCommunityTable": {
#                 "snmpCommunityEntry": {
#                     "snmpCommunityIndex": "public",
#                     "snmpCommunityName": "public",
#                     "snmpCommunitySecurityName": "public",
#                     "snmpCommunityContextEngineID": "80:00:61:81:05:01",
#                     "snmpCommunityContextName": null,
#                     "snmpCommunityTransportTag": null,
#                     "snmpCommunityStorageType": "permanent"
#                 }
#             }
#         },
#         "SNMP-NOTIFICATION-MIB": {
#             "@xmlns": "http://tail-f.com/ns/mibs/SNMP-NOTIFICATION-MIB/200210140000Z",
#             "snmpNotifyTable": {
#                 "snmpNotifyEntry": [
#                     {
#                         "snmpNotifyName": "std_v1_trap",
#                         "snmpNotifyTag": "std_v1_trap",
#                         "snmpNotifyType": "trap",
#                         "snmpNotifyStorageType": "nonVolatile"
#                     },
#                     {
#                         "snmpNotifyName": "std_v2_inform",
#                         "snmpNotifyTag": "std_v2_inform",
#                         "snmpNotifyType": "inform",
#                         "snmpNotifyStorageType": "nonVolatile"
#                     },
#                     {
#                         "snmpNotifyName": "std_v2_trap",
#                         "snmpNotifyTag": "std_v2_trap",
#                         "snmpNotifyType": "trap",
#                         "snmpNotifyStorageType": "nonVolatile"
#                     },
#                     {
#                         "snmpNotifyName": "std_v3_inform",
#                         "snmpNotifyTag": "std_v3_inform",
#                         "snmpNotifyType": "inform",
#                         "snmpNotifyStorageType": "nonVolatile"
#                     },
#                     {
#                         "snmpNotifyName": "std_v3_trap",
#                         "snmpNotifyTag": "std_v3_trap",
#                         "snmpNotifyType": "trap",
#                         "snmpNotifyStorageType": "nonVolatile"
#                     }
#                 ]
#             }
#         },
#         "SNMP-TARGET-MIB": {
#             "@xmlns": "http://tail-f.com/ns/mibs/SNMP-TARGET-MIB/200210140000Z",
#             "snmpTargetAddrTable": {
#                 "snmpTargetAddrEntry": [
#                     {
#                         "snmpTargetAddrName": "127.0.0.1 v1",
#                         "snmpTargetAddrTDomain": "1.3.6.1.6.1.1",
#                         "snmpTargetAddrTAddress": "127.0.0.1.19.136",
#                         "snmpTargetAddrTimeout": "1500",
#                         "snmpTargetAddrRetryCount": "3",
#                         "snmpTargetAddrTagList": "std_v1_trap std_trap std_v1_inform std_inform",
#                         "snmpTargetAddrParams": "target_v1",
#                         "snmpTargetAddrStorageType": "nonVolatile",
#                         "snmpTargetAddrEngineID": null,
#                         "snmpTargetAddrTMask": null,
#                         "snmpTargetAddrMMS": "2048",
#                         "enabled": "true"
#                     },
#                     {
#                         "snmpTargetAddrName": "127.0.0.1 v2",
#                         "snmpTargetAddrTDomain": "1.3.6.1.6.1.1",
#                         "snmpTargetAddrTAddress": "127.0.0.1.23.112",
#                         "snmpTargetAddrTimeout": "1500",
#                         "snmpTargetAddrRetryCount": "3",
#                         "snmpTargetAddrTagList": "std_v2_trap std_trap std_v2_inform std_inform",
#                         "snmpTargetAddrParams": "target_v2",
#                         "snmpTargetAddrStorageType": "nonVolatile",
#                         "snmpTargetAddrEngineID": null,
#                         "snmpTargetAddrTMask": null,
#                         "snmpTargetAddrMMS": "2048",
#                         "enabled": "true"
#                     },
#                     {
#                         "snmpTargetAddrName": "127.0.0.1 v3",
#                         "snmpTargetAddrTDomain": "1.3.6.1.6.1.1",
#                         "snmpTargetAddrTAddress": "127.0.0.1.27.88",
#                         "snmpTargetAddrTimeout": "1500",
#                         "snmpTargetAddrRetryCount": "3",
#                         "snmpTargetAddrTagList": "std_v3_trap std_trap",
#                         "snmpTargetAddrParams": "trap_target_v3",
#                         "snmpTargetAddrStorageType": "nonVolatile",
#                         "snmpTargetAddrEngineID": null,
#                         "snmpTargetAddrTMask": null,
#                         "snmpTargetAddrMMS": "2048",
#                         "enabled": "true"
#                     },
#                     {
#                         "snmpTargetAddrName": "127.0.0.1 v3.inform",
#                         "snmpTargetAddrTDomain": "1.3.6.1.6.1.1",
#                         "snmpTargetAddrTAddress": "127.0.0.1.27.88",
#                         "snmpTargetAddrTimeout": "1500",
#                         "snmpTargetAddrRetryCount": "3",
#                         "snmpTargetAddrTagList": "std_v3_inform std_inform",
#                         "snmpTargetAddrParams": "inform_target_v3",
#                         "snmpTargetAddrStorageType": "nonVolatile",
#                         "snmpTargetAddrEngineID": "80:00:1f:88:04:74:65:73:74:69:6e:67",
#                         "snmpTargetAddrTMask": null,
#                         "snmpTargetAddrMMS": "2048",
#                         "enabled": "true"
#                     }
#                 ]
#             },
#             "snmpTargetParamsTable": {
#                 "snmpTargetParamsEntry": [
#                     {
#                         "snmpTargetParamsName": "inform_target_v3",
#                         "snmpTargetParamsMPModel": "3",
#                         "snmpTargetParamsSecurityModel": "3",
#                         "snmpTargetParamsSecurityName": "remote",
#                         "snmpTargetParamsSecurityLevel": "noAuthNoPriv",
#                         "snmpTargetParamsStorageType": "nonVolatile"
#                     },
#                     {
#                         "snmpTargetParamsName": "target_v1",
#                         "snmpTargetParamsMPModel": "0",
#                         "snmpTargetParamsSecurityModel": "1",
#                         "snmpTargetParamsSecurityName": "public",
#                         "snmpTargetParamsSecurityLevel": "noAuthNoPriv",
#                         "snmpTargetParamsStorageType": "nonVolatile"
#                     },
#                     {
#                         "snmpTargetParamsName": "target_v2",
#                         "snmpTargetParamsMPModel": "1",
#                         "snmpTargetParamsSecurityModel": "2",
#                         "snmpTargetParamsSecurityName": "public",
#                         "snmpTargetParamsSecurityLevel": "noAuthNoPriv",
#                         "snmpTargetParamsStorageType": "nonVolatile"
#                     },
#                     {
#                         "snmpTargetParamsName": "trap_target_v3",
#                         "snmpTargetParamsMPModel": "3",
#                         "snmpTargetParamsSecurityModel": "3",
#                         "snmpTargetParamsSecurityName": "public",
#                         "snmpTargetParamsSecurityLevel": "noAuthNoPriv",
#                         "snmpTargetParamsStorageType": "nonVolatile"
#                     }
#                 ]
#             }
#         },
#         "SNMP-USER-BASED-SM-MIB": {
#             "@xmlns": "http://tail-f.com/ns/mibs/SNMP-USER-BASED-SM-MIB/200210160000Z",
#             "usmUserTable": {
#                 "usmUserEntry": [
#                     {
#                         "usmUserEngineID": "80:00:61:81:05:01",
#                         "usmUserName": "initial",
#                         "usmUserSecurityName": "initial",
#                         "usmUserAuthProtocol": "1.3.6.1.6.3.10.1.1.1",
#                         "usmUserPrivProtocol": "1.3.6.1.6.3.10.1.2.1",
#                         "usmUserStorageType": "nonVolatile"
#                     },
#                     {
#                         "usmUserEngineID": "80:00:61:81:05:01",
#                         "usmUserName": "initial_auth",
#                         "usmUserSecurityName": "initial_auth",
#                         "usmUserAuthProtocol": "1.3.6.1.6.3.10.1.1.2",
#                         "usmUserPrivProtocol": "1.3.6.1.6.3.10.1.2.1",
#                         "usmUserStorageType": "nonVolatile",
#                         "usmUserAuthKey": "10:2c:bd:65:e3:eb:e2:16:0d:63:db:23:73:f3:17:b2"
#                     },
#                     {
#                         "usmUserEngineID": "80:00:61:81:05:01",
#                         "usmUserName": "initial_authPriv",
#                         "usmUserSecurityName": "initial_authPriv",
#                         "usmUserAuthProtocol": "1.3.6.1.6.3.10.1.1.2",
#                         "usmUserPrivProtocol": "1.3.6.1.6.3.10.1.2.2",
#                         "usmUserStorageType": "nonVolatile",
#                         "usmUserAuthKey": "10:2c:bd:65:e3:eb:e2:16:0d:63:db:23:73:f3:17:b2",
#                         "usmUserPrivKey": "10:2c:bd:65:e3:eb:e2:16:0d:63:db:23:73:f3:17:b2"
#                     }
#                 ]
#             }
#         },
#         "SNMP-VIEW-BASED-ACM-MIB": {
#             "@xmlns": "http://tail-f.com/ns/mibs/SNMP-VIEW-BASED-ACM-MIB/200210160000Z",
#             "vacmSecurityToGroupTable": {
#                 "vacmSecurityToGroupEntry": [
#                     {
#                         "vacmSecurityModel": "1",
#                         "vacmSecurityName": "public",
#                         "vacmGroupName": "all-rights",
#                         "vacmSecurityToGroupStorageType": "nonVolatile"
#                     },
#                     {
#                         "vacmSecurityModel": "2",
#                         "vacmSecurityName": "public",
#                         "vacmGroupName": "all-rights",
#                         "vacmSecurityToGroupStorageType": "nonVolatile"
#                     },
#                     {
#                         "vacmSecurityModel": "3",
#                         "vacmSecurityName": "initial",
#                         "vacmGroupName": "initial",
#                         "vacmSecurityToGroupStorageType": "nonVolatile"
#                     },
#                     {
#                         "vacmSecurityModel": "3",
#                         "vacmSecurityName": "initial_auth",
#                         "vacmGroupName": "initial",
#                         "vacmSecurityToGroupStorageType": "nonVolatile"
#                     },
#                     {
#                         "vacmSecurityModel": "3",
#                         "vacmSecurityName": "initial_authPriv",
#                         "vacmGroupName": "initial",
#                         "vacmSecurityToGroupStorageType": "nonVolatile"
#                     }
#                 ]
#             },
#             "vacmAccessTable": {
#                 "vacmAccessEntry": [
#                     {
#                         "vacmGroupName": "initial",
#                         "vacmAccessContextPrefix": null,
#                         "vacmAccessSecurityModel": "3",
#                         "vacmAccessSecurityLevel": "noAuthNoPriv",
#                         "vacmAccessContextMatch": "exact",
#                         "vacmAccessReadViewName": "internet",
#                         "vacmAccessWriteViewName": "internet",
#                         "vacmAccessNotifyViewName": "internet",
#                         "vacmAccessStorageType": "nonVolatile"
#                     },
#                     {
#                         "vacmGroupName": "initial",
#                         "vacmAccessContextPrefix": null,
#                         "vacmAccessSecurityModel": "3",
#                         "vacmAccessSecurityLevel": "authNoPriv",
#                         "vacmAccessContextMatch": "exact",
#                         "vacmAccessReadViewName": "internet",
#                         "vacmAccessWriteViewName": "internet",
#                         "vacmAccessNotifyViewName": "internet",
#                         "vacmAccessStorageType": "nonVolatile"
#                     },
#                     {
#                         "vacmGroupName": "initial",
#                         "vacmAccessContextPrefix": null,
#                         "vacmAccessSecurityModel": "3",
#                         "vacmAccessSecurityLevel": "authPriv",
#                         "vacmAccessContextMatch": "exact",
#                         "vacmAccessReadViewName": "internet",
#                         "vacmAccessWriteViewName": "internet",
#                         "vacmAccessNotifyViewName": "internet",
#                         "vacmAccessStorageType": "nonVolatile"
#                     },
#                     {
#                         "vacmGroupName": "all-rights",
#                         "vacmAccessContextPrefix": null,
#                         "vacmAccessSecurityModel": "0",
#                         "vacmAccessSecurityLevel": "noAuthNoPriv",
#                         "vacmAccessContextMatch": "exact",
#                         "vacmAccessReadViewName": "internet",
#                         "vacmAccessWriteViewName": "internet",
#                         "vacmAccessNotifyViewName": "internet",
#                         "vacmAccessStorageType": "nonVolatile"
#                     }
#                 ]
#             },
#             "vacmViewTreeFamilyTable": {
#                 "vacmViewTreeFamilyEntry": {
#                     "vacmViewTreeFamilyViewName": "internet",
#                     "vacmViewTreeFamilySubtree": "1.3.6.1",
#                     "vacmViewTreeFamilyMask": null,
#                     "vacmViewTreeFamilyType": "included",
#                     "vacmViewTreeFamilyStorageType": "nonVolatile"
#                 }
#             }
#         },
#         "SNMPv2-MIB": {
#             "@xmlns": "http://tail-f.com/ns/mibs/SNMPv2-MIB/200210160000Z",
#             "system": {
#                 "sysContact": null,
#                 "sysName": null,
#                 "sysLocation": null
#             },
#             "snmp": {
#                 "snmpEnableAuthenTraps": "disabled"
#             }
#         },
#         "fpd": {
#             "@xmlns": "http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-fpd-infra-cli-fpd",
#             "config": {
#                 "auto-upgrade": "disable"
#             }
#         },
#         "sdr-config": {
#             "@xmlns": "http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-sdr-mgr",
#             "sdr": {
#                 "name": "default-sdr",
#                 "resources": {
#                     "card-type": [
#                         {
#                             "type": "RP",
#                             "vm-memory": "2",
#                             "vm-cpu": "1"
#                         },
#                         {
#                             "type": "LC",
#                             "vm-memory": "1",
#                             "vm-cpu": "1"
#                         }
#                     ]
#                 },
#                 "location": {
#                     "node-location": "all"
#                 }
#             }
#         },
#         "private-sdr": {
#             "@xmlns": "http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-sdr-mgr",
#             "sdr-name": {
#                 "name": "default-sdr",
#                 "id": "2",
#                 "lead_rack0": "0",
#                 "lead_rack1": "0",
#                 "pairing": {
#                     "num": "0",
#                     "second_exist": "false",
#                     "rp1_rack": "0",
#                     "rp1_slot": "0"
#                 }
#             }
#         },
#         "service": {
#             "@xmlns": "http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-services",
#             "cli": {
#                 "interactive": {
#                     "enabled": "true"
#                 }
#             }
#         },
#         "interfaces": {
#             "@xmlns": "http://openconfig.net/yang/interfaces",
#             "interface": [
#                 {
#                     "name": "MgmtEth0/RP0/CPU0/0",
#                     "config": {
#                         "name": "MgmtEth0/RP0/CPU0/0",
#                         "type": {
#                             "@xmlns:idx": "urn:ietf:params:xml:ns:yang:iana-if-type",
#                             "#text": "idx:ethernetCsmacd"
#                         },
#                         "enabled": "true",
#                         "description": "*** MANAGEMENT INTERFACE ***"
#                     },
#                     "ethernet": {
#                         "@xmlns": "http://openconfig.net/yang/interfaces/ethernet",
#                         "config": {
#                             "auto-negotiate": "false"
#                         }
#                     },
#                     "subinterfaces": {
#                         "subinterface": {
#                             "index": "0"
#                         }
#                     }
#                 },
#                 {
#                     "name": "GigabitEthernet0/0/0/0",
#                     "config": {
#                         "name": "GigabitEthernet0/0/0/0",
#                         "type": {
#                             "@xmlns:idx": "urn:ietf:params:xml:ns:yang:iana-if-type",
#                             "#text": "idx:ethernetCsmacd"
#                         },
#                         "enabled": "false"
#                     },
#                     "ethernet": {
#                         "@xmlns": "http://openconfig.net/yang/interfaces/ethernet",
#                         "config": {
#                             "auto-negotiate": "false"
#                         }
#                     }
#                 },
#                 {
#                     "name": "GigabitEthernet0/0/0/1",
#                     "config": {
#                         "name": "GigabitEthernet0/0/0/1",
#                         "type": {
#                             "@xmlns:idx": "urn:ietf:params:xml:ns:yang:iana-if-type",
#                             "#text": "idx:ethernetCsmacd"
#                         },
#                         "enabled": "false"
#                     },
#                     "ethernet": {
#                         "@xmlns": "http://openconfig.net/yang/interfaces/ethernet",
#                         "config": {
#                             "auto-negotiate": "false"
#                         }
#                     }
#                 },
#                 {
#                     "name": "GigabitEthernet0/0/0/2",
#                     "config": {
#                         "name": "GigabitEthernet0/0/0/2",
#                         "type": {
#                             "@xmlns:idx": "urn:ietf:params:xml:ns:yang:iana-if-type",
#                             "#text": "idx:ethernetCsmacd"
#                         },
#                         "enabled": "false"
#                     },
#                     "ethernet": {
#                         "@xmlns": "http://openconfig.net/yang/interfaces/ethernet",
#                         "config": {
#                             "auto-negotiate": "false"
#                         }
#                     }
#                 },
#                 {
#                     "name": "GigabitEthernet0/0/0/3",
#                     "config": {
#                         "name": "GigabitEthernet0/0/0/3",
#                         "type": {
#                             "@xmlns:idx": "urn:ietf:params:xml:ns:yang:iana-if-type",
#                             "#text": "idx:ethernetCsmacd"
#                         },
#                         "enabled": "false"
#                     },
#                     "ethernet": {
#                         "@xmlns": "http://openconfig.net/yang/interfaces/ethernet",
#                         "config": {
#                             "auto-negotiate": "false"
#                         }
#                     }
#                 },
#                 {
#                     "name": "GigabitEthernet0/0/0/4",
#                     "config": {
#                         "name": "GigabitEthernet0/0/0/4",
#                         "type": {
#                             "@xmlns:idx": "urn:ietf:params:xml:ns:yang:iana-if-type",
#                             "#text": "idx:ethernetCsmacd"
#                         },
#                         "enabled": "false"
#                     },
#                     "ethernet": {
#                         "@xmlns": "http://openconfig.net/yang/interfaces/ethernet",
#                         "config": {
#                             "auto-negotiate": "false"
#                         }
#                     }
#                 }
#             ]
#         },
#         "lacp": {
#             "@xmlns": "http://openconfig.net/yang/lacp",
#             "interfaces": {
#                 "interface": [
#                     {
#                         "name": "MgmtEth0/RP0/CPU0/0",
#                         "config": {
#                             "name": "MgmtEth0/RP0/CPU0/0"
#                         }
#                     },
#                     {
#                         "name": "GigabitEthernet0/0/0/0",
#                         "config": {
#                             "name": "GigabitEthernet0/0/0/0"
#                         }
#                     },
#                     {
#                         "name": "GigabitEthernet0/0/0/1",
#                         "config": {
#                             "name": "GigabitEthernet0/0/0/1"
#                         }
#                     },
#                     {
#                         "name": "GigabitEthernet0/0/0/2",
#                         "config": {
#                             "name": "GigabitEthernet0/0/0/2"
#                         }
#                     },
#                     {
#                         "name": "GigabitEthernet0/0/0/3",
#                         "config": {
#                             "name": "GigabitEthernet0/0/0/3"
#                         }
#                     },
#                     {
#                         "name": "GigabitEthernet0/0/0/4",
#                         "config": {
#                             "name": "GigabitEthernet0/0/0/4"
#                         }
#                     }
#                 ]
#             }
#         },
#         "network-instances": {
#             "@xmlns": "http://openconfig.net/yang/network-instance",
#             "network-instance": {
#                 "name": "default",
#                 "config": {
#                     "name": "default"
#                 },
#                 "protocols": {
#                     "protocol": {
#                         "identifier": {
#                             "@xmlns:idx": "http://openconfig.net/yang/policy-types",
#                             "#text": "idx:STATIC"
#                         },
#                         "name": "DEFAULT",
#                         "config": {
#                             "identifier": {
#                                 "@xmlns:idx": "http://openconfig.net/yang/policy-types",
#                                 "#text": "idx:STATIC"
#                             },
#                             "name": "DEFAULT"
#                         },
#                         "static-routes": {
#                             "static": {
#                                 "prefix": "0.0.0.0/0",
#                                 "config": {
#                                     "prefix": "0.0.0.0/0"
#                                 },
#                                 "next-hops": {
#                                     "next-hop": {
#                                         "index": "**192.168.122.1**",
#                                         "config": {
#                                             "index": "**192.168.122.1**",
#                                             "next-hop": "192.168.122.1"
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }

# %%
get_xml = get(HOST, PORT, USER, PASS)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-15843d975b9d> in <module>
# ----> 1 get_xml = get(HOST, PORT, USER, PASS)
#
# <ipython-input-1-05151b593e1c> in get(HOST, PORT, USER, PASS)
#      14                          hostkey_verify=False, device_params={'name': name},
#      15                          look_for_keys=False, allow_agent=False) as m:
# ---> 16         return m.get(source='running').data_xml
#      17
#      18
#
# ~/.local/share/virtualenvs/automarked-pZFTlo7o/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     214                    async_mode=self._async_mode,
#     215                    timeout=self._timeout,
# --> 216                    raise_mode=self._raise_mode).request(*args, **kwds)
#     217
#     218     def locked(self, target):
#
# TypeError: request() got an unexpected keyword argument 'source'
